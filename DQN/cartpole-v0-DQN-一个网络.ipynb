# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
import random
import numpy as np
import numpy
from collections import deque
import gym

# %%
class DQN:
    def __init__(self, action_size):
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.95
        self.learning_rate = 0.001
        self.model = self.buildModel()
    
    def buildModel(self):
        input = Input(shape=(4, ))
        x = Dense(16, activation='relu')(input)
        x = Dense(16, activation='relu')(x)
        x = Dense(2, activation='linear')(x)
        model = Model(inputs=input, outputs=x)
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return model
    
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])
    
    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1)
        if self.epsilon > self.epsilon_min:
            self.epsilon *=self.epsilon_decay

            
def main(episodes, epochss):
    
    env = gym.make('CartPole-v0')
    agent = DQN(2)
    for episode in range(episodes):
        state = env.reset()
        state = np.array(state).reshape(-1, 4)
        
        for epoch in range(epochss):
            env.render()
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            next_state = np.array(next_state).reshape(-1, 4)
            agent.remember = (state, action, reward, next_state, done)
            
            state = next_state
            
            if done:
                print("episode:{}/{}, score:{}".format(episode, episodes, epoch))
                break
    agent.replay(16)
    
if __name__ =="__main__":
    main(1000, 1000)
# Out:
# c:\users\zhchxiao\anaconda3\envs\pytorch\lib\site-packages\gym\envs\registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# episode:0/1000, score:14
# episode:1/1000, score:10
# episode:2/1000, score:21
# episode:3/1000, score:14
# episode:4/1000, score:15
# episode:5/1000, score:28
# episode:6/1000, score:12
# episode:7/1000, score:12
# episode:8/1000, score:11
# episode:9/1000, score:25
# episode:10/1000, score:16
# episode:11/1000, score:21
# episode:12/1000, score:17
# episode:13/1000, score:22
# episode:14/1000, score:16
# episode:15/1000, score:27
# episode:16/1000, score:19
# episode:17/1000, score:25
# episode:18/1000, score:38
# episode:19/1000, score:13
# episode:20/1000, score:26
# episode:21/1000, score:16
# episode:22/1000, score:9
# episode:23/1000, score:36
# episode:24/1000, score:17
# episode:25/1000, score:22
# episode:26/1000, score:14
# episode:27/1000, score:10
# episode:28/1000, score:47
# episode:29/1000, score:13
# episode:30/1000, score:12
# episode:31/1000, score:53
# episode:32/1000, score:15
# episode:33/1000, score:12
# episode:34/1000, score:32
# episode:35/1000, score:10
# episode:36/1000, score:21
# episode:37/1000, score:20
# episode:38/1000, score:33
# episode:39/1000, score:18
# episode:40/1000, score:55
# episode:41/1000, score:32
# episode:42/1000, score:51
# episode:43/1000, score:38
# episode:44/1000, score:59
# episode:45/1000, score:12
# episode:46/1000, score:16
# episode:47/1000, score:12
# episode:48/1000, score:18
# episode:49/1000, score:26
# episode:50/1000, score:26
# episode:51/1000, score:19
# episode:52/1000, score:12
# episode:53/1000, score:20
# episode:54/1000, score:13
# episode:55/1000, score:21
# episode:56/1000, score:30
# episode:57/1000, score:10
# episode:58/1000, score:32
# episode:59/1000, score:16
# episode:60/1000, score:31
# episode:61/1000, score:25
# episode:62/1000, score:30
# episode:63/1000, score:20
# episode:64/1000, score:8
# episode:65/1000, score:24
# episode:66/1000, score:17
# episode:67/1000, score:13
# episode:68/1000, score:22
# episode:69/1000, score:54
# episode:70/1000, score:41
# episode:71/1000, score:35
# episode:72/1000, score:25
# episode:73/1000, score:34
# episode:74/1000, score:11
# episode:75/1000, score:17
# episode:76/1000, score:35
# episode:77/1000, score:13
# episode:78/1000, score:45
# episode:79/1000, score:9
# episode:80/1000, score:23
# episode:81/1000, score:17
# episode:82/1000, score:26
# episode:83/1000, score:12
# episode:84/1000, score:26
# episode:85/1000, score:16
# episode:86/1000, score:15
# episode:87/1000, score:17
# episode:88/1000, score:30
# episode:89/1000, score:14
# episode:90/1000, score:11
# episode:91/1000, score:24
# episode:92/1000, score:14
# episode:93/1000, score:40
# episode:94/1000, score:34
# episode:95/1000, score:9
# episode:96/1000, score:20
# episode:97/1000, score:19
# episode:98/1000, score:14
# episode:99/1000, score:20
# episode:100/1000, score:44
# episode:101/1000, score:12
# episode:102/1000, score:13
# episode:103/1000, score:11
# episode:104/1000, score:38
# episode:105/1000, score:17
# episode:106/1000, score:12
# episode:107/1000, score:40
# episode:108/1000, score:12
# episode:109/1000, score:10
# episode:110/1000, score:15
# episode:111/1000, score:19
# episode:112/1000, score:11
# episode:113/1000, score:18
# episode:114/1000, score:25
# episode:115/1000, score:7
# episode:116/1000, score:16
# episode:117/1000, score:17
# episode:118/1000, score:43
# episode:119/1000, score:13
# episode:120/1000, score:15
# episode:121/1000, score:68
# episode:122/1000, score:16
# episode:123/1000, score:18
# episode:124/1000, score:8
# episode:125/1000, score:23
# episode:126/1000, score:21
# episode:127/1000, score:14
# episode:128/1000, score:14
# episode:129/1000, score:15
# episode:130/1000, score:38
# episode:131/1000, score:15
# episode:132/1000, score:34
# episode:133/1000, score:14
# episode:134/1000, score:12
# episode:135/1000, score:12
# episode:136/1000, score:13
# episode:137/1000, score:10
# episode:138/1000, score:16
# episode:139/1000, score:16
# episode:140/1000, score:21
# episode:141/1000, score:16
# episode:142/1000, score:25
# episode:143/1000, score:19
# episode:144/1000, score:15
# episode:145/1000, score:12
# episode:146/1000, score:20
# episode:147/1000, score:12
# episode:148/1000, score:31
# episode:149/1000, score:15
# episode:150/1000, score:20
# episode:151/1000, score:12
# episode:152/1000, score:12
# episode:153/1000, score:16
# episode:154/1000, score:19
# episode:155/1000, score:11
# episode:156/1000, score:42
# episode:157/1000, score:16
# episode:158/1000, score:15
# episode:159/1000, score:15
# episode:160/1000, score:12
# episode:161/1000, score:21
# episode:162/1000, score:12
# episode:163/1000, score:22
# episode:164/1000, score:14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ae1d8c24e689> in <module>
#      64
#      65 if __name__ =="__main__":
# ---> 66     main(1000, 1000)
#
# <ipython-input-3-ae1d8c24e689> in main(episodes, epochss)
#      50
#      51         for epoch in range(epochss):
# ---> 52             env.render()
#      53             action = agent.act(state)
#      54             next_state, reward, done, _ = env.step(action)
#
# c:\users\zhchxiao\anaconda3\envs\pytorch\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     273
#     274     def render(self, mode='human', **kwargs):
# --> 275         return self.env.render(mode, **kwargs)
#     276
#     277     def close(self):
#
# c:\users\zhchxiao\anaconda3\envs\pytorch\lib\site-packages\gym\envs\classic_control\cartpole.py in render(self, mode)
#     186         self.poletrans.set_rotation(-x[2])
#     187
# --> 188         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#     189
#     190     def close(self):
#
# c:\users\zhchxiao\anaconda3\envs\pytorch\lib\site-packages\gym\envs\classic_control\rendering.py in render(self, return_rgb_array)
#      80
#      81     def render(self, return_rgb_array=False):
# ---> 82         glClearColor(1,1,1,1)
#      83         self.window.clear()
#      84         self.window.switch_to()
#
# c:\users\zhchxiao\anaconda3\envs\pytorch\lib\site-packages\pyglet\gl\lib.py in errcheck(result, func, arguments)
#     100         raise GLException('No GL context; create a Window first')
#     101     if not context._gl_begin:
# --> 102         error = gl.glGetError()
#     103         if error:
#     104             msg = ctypes.cast(gl.gluErrorString(error), ctypes.c_char_p).value
#
# KeyboardInterrupt:

# %%
import gym
import random
env = gym.make('CartPole-v0')

while True:
    env.reset()
    env.render()
